# %%
import pandas as pd
df = pd.read_csv("quotes/quotes_to_post.csv")

# %%
df
# Out:
#                                          Pic  Pic #of char  \
# 0                  Love is a state of being.            25
# 1                    Love is not an emotion.            23
# 2        Love is not directed to one person.            35
# 3                        Love is contagious.            19
# 4                  Love is patient and kind.            25
# ..                                       ...           ...
# 61  Do not try to undersnd love, just do it.            40
# 62                    Happiness is attitude.            22
# 63                     Happiness is a skill.            21
# 64                         Happiness is now.            17
# 65                      Happiness is giving.            20
#
#                      Description - can be same as pic direct quote  \
# 0   Your love is not outside; it is deep within yo...          Yes
# 1   Love is a state of being in harmony with oneself.          Yes
# 2   Believing that we only get one soulmate is a t...          Yes
# 3   Someone who experienced true love wants to sha...           No
# 4   The heart in love remains soft and sensitive. ...          Yes
# ..                                                ...          ...
# 61  The wise are wise only because they love. The ...          Yes
# 62  The secret of happiness is not in doing what o...          Yes
# 63  Happiness is not something readymade. It comes...          Yes
# 64  There is no way to happiness, happiness is the...          Yes
# 65  Happiness doesn't result from what we get, but...          Yes
#
#     Description #of char            Reference Provider Ready for production  \
# 0                     96        Eckhart Tolle    Maria                  yes
# 1                     49        Anodea Judith    Maria                  yes
# 2                    227  Seth Meyers, Psy.D.    Maria                  yes
# 3                     61                Maria    Maria                  yes
# 4                    152     Anthony de Mello    Maria                  yes
# ..                   ...                  ...      ...                  ...
# 61                   110         Paulo Coelho    Maria                  yes
# 62                    85      James M. Barrie    Maria                  yes
# 63                    70           Dalai Lama    Maria                  yes
# 64                    51      Thich Nhat Hanh    Maria                  yes
# 65                    65          Ben Carson     Maria                  yes
#
#    Maria Aproved Ben Approuved
# 0              1             1
# 1              1             1
# 2              1             1
# 3              1             1
# 4              1             1
# ..           ...           ...
# 61             1             1
# 62             1             1
# 63             1             1
# 64             1             1
# 65             1             1
#
# [65 rows x 10 columns]

# %%
df = df[df["Ready for production"]=="yes"]

# %%
from PIL import Image, ImageDraw, ImageFont
import textwrap


def quote_on_image(row_quote, img, font):
    quote = row_quote["Pic"].strip()

    para = textwrap.wrap(quote, width=32)
    MAX_W, MAX_H = img.size
    draw = ImageDraw.Draw(img)

    text_h = draw.textsize(para[0], font=font)[1] *len(para)
    padding = 20
    starting_h = ((MAX_H - text_h) + ((len(para)-1) * padding)) / 2

    for line in para:
        w, h = draw.textsize(line, font=font)
        draw.text(((MAX_W - w) / 2, starting_h), line,(0,0,0), font=font)
        starting_h += h + padding
        
    if row_quote["direct quote"] == "Yes" and (row_quote["Reference"] !="Maria" or row_quote["Reference"] !="Ben's notes"):
        direct_font = ImageFont.truetype('/System/Library/Fonts/Supplemental/Andale Mono.ttf', 70)
        w, h = draw.textsize(row_quote["Reference"], font=direct_font)
        draw.text(((MAX_W - w) / 2, starting_h + 3*padding), f"by {row_quote['Reference']}",(0,0,0), font=direct_font)
    return img

def generate_images_from_df(df):
    img = Image.open("quotes/background/deep_dreath_crop.png")
    font = ImageFont.truetype('/System/Library/Fonts/Supplemental/Andale Mono.ttf', 135)
    
    for index, row in df.iterrows():
        img = Image.open("quotes/background/deep_dreath_crop.png")
        img = quote_on_image(row, img, font)
        img.save(f"quotes/images/img_quote_{index}.png")

# %%
generate_images_from_df(df)
